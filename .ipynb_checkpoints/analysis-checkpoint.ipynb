# %%
import pandas as pd
import matplotlib.pyplot as plt
from utility import check_columns
import scipy.stats as st
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-0c43379b76e5> in <module>
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 3 from utility import check_columns
#       4 import scipy.stats as st
#
# ImportError: cannot import name 'check_columns' from 'utility' (C:\Users\berry\unionDensityProject\utility.py)

# %%
income_data = pd.read_csv("./raw_data/income_Distribution_OECD_013021.csv")
income_data.head()

# %% [markdown]
# ## Gini index
# - < 0.2 represents perfect income equality,
# - 0.2–0.3 relative equality,
# - 0.3–0.4 adequate equality,
# - 0.4–0.5 big income gap,
# - above 0.5 represents severe income gap.
# ## Therefore, the warning level of Gini index is 0.4.

# %% [markdown]
# ## Read union data from ouputfile.csv

# %%
union_df = pd.read_csv("raw_data/uniondata.csv")
union_df.head()
# Out:
#    Unnamed: 0  Country               Source                Series  Year  \
# 0          54  Hungary          Survey data  Trade union  density  2004
# 1          55  Hungary          Survey data  Trade union  density  2009
# 2          56  Hungary          Survey data  Trade union  density  2015
# 3          94   Poland  Administrative data  Trade union  density  1999
# 4          95   Poland  Administrative data  Trade union  density  2000
#
#          Unit  Value
# 0  Percentage   16.8
# 1  Percentage   11.9
# 2  Percentage    9.0
# 3  Percentage   29.1
# 4  Percentage   24.7

# %% [markdown]
# ## Gini CPI data from gini_cpi.csv

# %%
gini_cpi_df = pd.read_csv("raw_data/gini_cpi.csv")
gini_cpi_df.head()
# Out:
#    Unnamed: 0    Country MEASURE         Age group  Year Unit Code       Unit  \
# 0           0  Australia    GINI  Total population  2012    0_TO_1  0-1 scale
# 1           1  Australia    GINI  Total population  2014    0_TO_1  0-1 scale
# 2           2  Australia    GINI  Total population  2016    0_TO_1  0-1 scale
# 3           3  Australia    GINI  Total population  2018    0_TO_1  0-1 scale
# 4           6  Australia    GINI  Total population  2010    0_TO_1  0-1 scale
#
#    Value
# 0  0.326
# 1  0.337
# 2  0.330
# 3  0.325
# 4  0.334

# %% [markdown]
# ### Merge union_df and gini_cpi-df
# - Get data of common years, 2009 to 2018
#     - union_df includes 21 years, from 1998 to 2018
#     - gini_cpi_df includes 11 years, from 2009 to 2019

# %%
df = pd.merge(union_df, gini_cpi_df, on=["Country", "Year"], suffixes=("_union", "_gini_cpi"))
df.head()
# Out:
#    Unnamed: 0_union  Country       Source                Series  Year  \
# 0                55  Hungary  Survey data  Trade union  density  2009
# 1                55  Hungary  Survey data  Trade union  density  2009
# 2                55  Hungary  Survey data  Trade union  density  2009
# 3                55  Hungary  Survey data  Trade union  density  2009
# 4                55  Hungary  Survey data  Trade union  density  2009
#
#    Unit_union  Value_union  Unnamed: 0_gini_cpi  MEASURE  \
# 0  Percentage         11.9                 7947     GINI
# 1  Percentage         11.9                 7959     GINI
# 2  Percentage         11.9                 7964  CPI2010
# 3  Percentage         11.9                 7976  CPI2010
# 4  Percentage         11.9                29555     GINI
#
#                        Age group Unit Code Unit_gini_cpi  Value_gini_cpi
# 0               Total population    0_TO_1     0-1 scale        0.241000
# 1               Total population    0_TO_1     0-1 scale        0.272000
# 2               Total population       IDX         Index       95.369304
# 3               Total population       IDX         Index       95.369304
# 4  Working age population: 18-65    0_TO_1     0-1 scale        0.245000

# %% [markdown]
# ### Remove unrelated columns

# %%
df_09_18 = df[["Country", "Year", "Value_union", "MEASURE", "Age group", "Value_gini_cpi"]]
df_09_18.head()
# Out:
#    Country  Year  Value_union  MEASURE                      Age group  \
# 0  Hungary  2009         11.9     GINI               Total population
# 1  Hungary  2009         11.9     GINI               Total population
# 2  Hungary  2009         11.9  CPI2010               Total population
# 3  Hungary  2009         11.9  CPI2010               Total population
# 4  Hungary  2009         11.9     GINI  Working age population: 18-65
#
#    Value_gini_cpi
# 0        0.241000
# 1        0.272000
# 2       95.369304
# 3       95.369304
# 4        0.245000

# %% [markdown]
# ### Working age population: 18~65

# %%
working_age = df_09_18[df_09_18["Age group"] == "Working age population: 18-65"]

gini_working = working_age[working_age["MEASURE"] == "GINI"]
gini_working = gini_working.drop_duplicates(subset=["Country","Year"])

cpi_working = working_age[working_age["MEASURE"] != "GINI"]
cpi_working = cpi_working.drop_duplicates(subset=["Country","Year"])

# Merge two dfs: gigi_working, cpi_working
# Drop unrelated columns
data_working = pd.merge(gini_working, cpi_working, on=["Country", "Year"])\
                        .drop(columns=["MEASURE_x", "Age group_x", "Value_union_y", "MEASURE_y", "Age group_y"])
# Rename columns 
data_working = data_working.rename(columns = {
                                                "Value_union_x": "Union %",
                                                "Value_gini_cpi_x": "Gini",
                                                "Value_gini_cpi_y": "CPI"
                                            })
data_working

data_working.to_csv("output/data_working.csv")

# %%
data_working
# Out:
#            Country  Year  Union %   Gini         CPI
# 0          Hungary  2009     11.9  0.245   95.369304
# 1          Hungary  2015      9.0  0.291  111.384411
# 2           Poland  2009     16.3  0.305   97.484226
# 3           Poland  2010     18.3  0.307  100.000000
# 4           Poland  2011     17.0  0.304  104.239401
# ..             ...   ...      ...    ...         ...
# 269  United States  2013     10.8  0.392  106.833852
# 270  United States  2014     10.7  0.389  108.566940
# 271  United States  2015     10.6  0.384  108.695723
# 272  United States  2016     10.3  0.385  110.067028
# 273  United States  2017     10.3  0.383  112.411595
#
# [274 rows x 5 columns]

# %% [markdown]
# ## Group countries by different regions
# - West Europe
# - Ease Europe
# - SCandinavian
# - US
# - Asia
# - Latin

# %%
west = ['United Kingdom', 'Spain', 'Austria', 'France', 'Germany', 'Ireland', 'Switzerland', 'Italy', 'Luxembourg', 
        'Greece', 'Israel', 'Netherlands', 'Belgium', 'Australia', 'New Zealand', 'Portugal', 'Turkey', 'Canada']
east =  ['Estonia', 'Czech Republic', 'Latvia', 'Lithuania', 'Hungary', 'Slovak Republic', 'Slovenia', 'Poland'] 
scandinavian = ['Norway', 'Finland' ,'Iceland', 'Sweden', 'Denmark']
us = ['United States']
asia = ['Korea', 'Japan']
latin = ['Mexico', 'Chile']

# %%
regions = {
    "West": west,
    "East": east,
    "Scandinavia": scandinavian,
    "US": us,
    "Asia": asia,
    "Latin": latin
}
working = data_working
working["Region"] = ""
for index, row in working_df.iterrows():
    for region in regions:
        if row.Country in regions[region]: 
            working.loc[index, "Region"] = region
            break
            
working.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-71fb78682c92> in <module>
#       9 working = data_working
#      10 working["Region"] = ""
# ---> 11 for index, row in working_df.iterrows():
#      12     for region in regions:
#      13         if row.Country in regions[region]:
#
# NameError: name 'working_df' is not defined

# %%
def plot_groupby(df, x, y, by, kind):
    is_setting_xlim, is_setting_ylim = True, True
    try:
        x_max = df[x].max()*1.05
        x_min = df[x].min()*0.95
    except:
        is_setting_xlim = False
        
    try:
        y_max = df[y].max()*1.05
        y_min = df[y].min()*0.95
    except:
        is_setting_ylim = False
        
    fig, ax = plt.subplots(3, 2, figsize=(20, 35))
    i = 0
    for member in df[by].value_counts().index:
        data_by = df[df[by] == member]
        current_ax = ax[i // 2][i % 2]
        
        if kind == "scatter":
            data_by.plot.scatter(x=x, y=y, ax=current_ax, grid=True)
        if kind == "hist":
            data_by.plot.hist(ax=current_ax)
        if kind == "bar":
            data_by.plot.bar(x=x, y=y,ax=current_ax)
            
        current_ax.set_title(f"{member}")
        if is_setting_xlim: current_ax.set_xlim(x_min, x_max)
        if is_setting_ylim: current_ax.set_ylim(y_min, y_max)

        i += 1

# %%
plot_groupby(working, x="Year", y="Gini", by="Region", kind="bar")

# %%
west_df = pd.DataFrame({"Country": west})
east_df = pd.DataFrame({"Country": east})
scand_df = pd.DataFrame({"Country": scandinavian})
us_df = pd.DataFrame({"Country": us})
asia_df = pd.DataFrame({"Country": asia})
latin_df = pd.DataFrame({"Country": latin})

# %%
# data_working[data_working["Country"] == west_df["Country"]]

west_filter = pd.merge(data_working, west_df, on=["Country"])
east_filter = pd.merge(data_working, east_df, on=["Country"])
scand_filter = pd.merge(data_working, scand_df, on=["Country"])
us_filter = pd.merge(data_working, us_df, on=["Country"])
asia_filter = pd.merge(data_working, asia_df, on=["Country"])
latin_filter = pd.merge(data_working, latin_df, on=["Country"])

df = {
    "west": {"df": west_filter, "x":0, "y":0, "color": "c"},
    "east": {"df": east_filter, "x":0, "y":1, "color": "m"},
    "scand": {"df":scand_filter, "x":1, "y":0, "color": "y"},
    "us": {"df":us_filter, "x":1, "y":1, "color": "b"},
    "asia": {"df":asia_filter, "x":2, "y":0, "color": "g"},
    "latin": {"df":latin_filter, "x":2, "y":1, "color": "r"}
}

# %%
df = {
    "west": {"df": west_filter, "x":0, "y":0, "color": "cyan"},
    "east": {"df": east_filter, "x":0, "y":1, "color": "purple"},
    "scand": {"df":scand_filter, "x":1, "y":0, "color": "oliver"},
    "us": {"df":us_filter, "x":1, "y":1, "color": "blue"},
    "asia": {"df":asia_filter, "x":2, "y":0, "color": "green"},
    "latin": {"df":latin_filter, "x":2, "y":1, "color": "red"}
}

# %%
fig, ax = plt.subplots(2, 3, figsize=(15, 6))

i = 0
for region in df:
#     x_position=df[region]["x"]
#     y_position=df[region]["y"]
    current_ax = ax[i // 3][i % 3]
    df[region]["df"].plot.scatter(x="Union %", y="Gini", ax=current_ax, grid=True)
#     ax[x_position][y_position].set_title(region)
    current_ax.set_ylim(0, 0.5)
    current_ax.set_xlim(0, 90)
    
    x = df[region]["df"]["Union %"]
    y = df[region]["df"]["Gini"]
    (slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = f"y = {round(slope, 3)}x + {round(intercept, 2)}"
    current_ax.plot(x, regress_values, "r-")
    
    current_ax.annotate(region, (50,0.45), fontsize=12, color="darkblue")
    current_ax.annotate(line_eq, (50,0.41), fontsize=10, color="darkblue")
    current_ax.annotate(f"rvalue: {round(rvalue,2)}", (50,0.37), fontsize=10, color="darkblue")
    
    correlation = "No correlation"
    if abs(rvalue) < 0.1:
        correlation = "No correlation"
    elif abs(rvalue) < 0.3:
        correlation = "Very weak correlation"
    elif abs(rvalue) < 0.5:
        correlation = "Weak correlation"
    elif abs(rvalue) < 0.7:
        correlation = "Moderate correlation"
    elif abs(rvalue) < 1:
        correlation = "Strong correlation"
    current_ax.annotate(correlation, (50,0.32), fontsize=10, color="red")    
    
    i += 1

# %%
data_working
data_working["Color"] = ""
data_working["Group"] = ""
data_working.head()
# Out:
#    Country  Year  Union %   Gini         CPI Color Group
# 0  Hungary  2009     11.9  0.245   95.369304
# 1  Hungary  2015      9.0  0.291  111.384411
# 2   Poland  2009     16.3  0.305   97.484226
# 3   Poland  2010     18.3  0.307  100.000000
# 4   Poland  2011     17.0  0.304  104.239401

# %%
for index, row in data_working.iterrows():
    if row["Country"] in west: 
        data_working.loc[index,"Group"] = 10
        data_working.loc[index,"Color"] = "c"
    if row["Country"] in east: 
        data_working.loc[index,"Group"] = 50 
        data_working.loc[index,"Color"] = "m"
    if row["Country"] in scandinavian: 
        data_working.loc[index,"Group"] = 95
        data_working.loc[index,"Color"] = "y"
    if row["Country"] in us: 
        data_working.loc[index,"Group"] = 130 
        data_working.loc[index,"Color"] = "b"
    if row["Country"] in asia: 
        data_working.loc[index,"Group"] = 160
        data_working.loc[index,"Color"] = "g"
    if row["Country"] in latin: 
        data_working.loc[index,"Group"] = 190
        data_working.loc[index,"Color"] = "r"
data_working.head()
# data_working.plot.scatter(x="Union %", y="Gini", c="Group", colormap="viridis")
# Out:
#    Country  Year  Union %   Gini         CPI Region  Group Color
# 0  Hungary  2009     11.9  0.245   95.369304   East   50.0     m
# 1  Hungary  2015      9.0  0.291  111.384411   East   50.0     m
# 2   Poland  2009     16.3  0.305   97.484226   East   50.0     m
# 3   Poland  2010     18.3  0.307  100.000000   East   50.0     m
# 4   Poland  2011     17.0  0.304  104.239401   East   50.0     m

# %%
from matplotlib import cm
cmap = cm.get_cmap('Spectral')

# %%
plt.figure(figsize=(15, 6))
i = 0
for region in df:
    x = df[region]["df"]["Union %"]
    y = df[region]["df"]["Gini"]
    plt.scatter(x, y, c=df[region]["color"] )
    plt.annotate(f"{region}: {df[region]['color']}", (80, 0.5 - i*0.02), fontsize=16, color="darkblue"  )
    i += 1

x = data_working["Union %"]
y = data_working["Gini"]
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
regress_values = x * slope + intercept
line_eq = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
plt.plot(x, regress_values, "r-")
plt.xlabel("Union %")
plt.ylabel("Gini")
plt.title("Gini vs. Union % All Countries")

# plt.annotate("With Latin: Red line", (55,0.5), fontsize=16, color="darkblue")
plt.annotate(line_eq, (60,0.48), fontsize=16, color="darkblue")
plt.annotate(f"rvalue: {round(rvalue,2)}", (60,0.46), fontsize=16, color="darkblue")

correlation = "No correlation"
if abs(rvalue) > 0.25:
    correlation = "Very weak correlation"
if abs(rvalue) > 0.3:
    correlation = "Weak correlation"
elif abs(rvalue) > 0.5:
    correlation = "Moderate correlation"
elif abs(rvalue) > 0.7:
    correlation = "Strong correlation"
plt.annotate(correlation, (60,0.44), fontsize=16, color="red")    


data_working1 = data_working[data_working["Region"] != "Latin"]
x1 = data_working1["Union %"]
y1 = data_working1["Gini"]
(slope1, intercept1, rvalue1, pvalue1, stderr1) = st.linregress(x1, y1)
regress_values1 = x1 * slope1 + intercept1
line_eq1 = f"y = {round(slope1, 2)}x + {round(intercept1, 2)}"
plt.plot(x1, regress_values1, "b-")

plt.annotate("Without Latin: Blue line", (55,0.42), fontsize=16, color="darkblue")
plt.annotate(line_eq1, (60,0.4), fontsize=16, color="darkblue")
plt.annotate(f"rvalue: {round(rvalue1,2)}", (60,0.38), fontsize=16, color="darkblue")

correlation = "No correlation"
if abs(rvalue1) < 0.3:
    correlation = "Very weak correlation"
elif abs(rvalue1) < 0.5:
    correlation = "Weak correlation"
elif abs(rvalue1) < 0.7:
    correlation = "Moderate correlation"
elif abs(rvalue1) < 1:
    correlation = "Strong correlation"
plt.annotate(correlation, (60,0.36), fontsize=16, color="red")
# Out:
# Text(60, 0.36, 'Moderate correlation')

# %%
def linear_regression(df, x_column, y_column, **kwargs):
    """
    df: dataframe
    x: string, column name
    y: string, column name
    """
    import matplotlib.pyplot as plt
    plt.figure(figsize=kwargs["figsize"]) if "figsize" in kwargs else plt.figure()
#     if not figsize:
#         plt.figure(figsize=figsize)
#     else:
#         plt.figure()
    x = df[x_column]
    y = df[y_column]
    plt.scatter(x, y)
    (slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
    plt.plot(x, regress_values, "r-")
    
    x_position = df[x_column].max()*0.75
    y_position = df[y_column].max()*0.9
    plt.annotate(line_eq, (x_position, y_position), fontsize=16, color="darkblue")
    plt.annotate(f"rvalue: {round(rvalue,2)}", (x_position, y_position*0.9), fontsize=16, color="darkblue")

# %%
linear_regression(data_working, x_column="Union %", y_column="CPI", figsize=(10,6))

# %%
def linear_regression1(df, x_col, y_col, **kwargs):
    """
    df: dataframe
    x: string, column name
    y: string, column name
    """
    import matplotlib.pyplot as plt
    import scipy.stats as st

    plt.figure(figsize=kwargs["figsize"]) if "figsize" in kwargs else plt.figure()

    x = df[x_col]
    y = df[y_col]
    color = df["Color"]
    plt.scatter(x, y, s=500, c=color, alpha=0.9)
    (slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = f"y = {round(slope, 3)}x + {round(intercept, 2)}"
    plt.plot(x, regress_values, "r-")

    xy = kwargs["xy"] if "xy" in kwargs else (x.max() * 0.75, y.max() * 0.95)
    fontsize = kwargs["fontsize"] if "fontsize" in kwargs else 12
    color = kwargs["color"] if "color" in kwargs else "red"
    plt.annotate(line_eq, xy, fontsize=fontsize, color=color)
    px, py = xy
    plt.annotate(f"rvalue: {round(rvalue, 2)}", (px, py * 0.97), fontsize=fontsize, color=color)
    correlation = "No correlation"
    if abs(rvalue) > 0.3:
        correlation = "Weak correlation"
    elif abs(ravlue) > 0.5:
        correlation = "Moderate correlation"
    elif abs(ravlue) > 0.7:
        correlation = "Strong correlation"
    plt.annotate(correlation, (px, py * 0.94), fontsize=fontsize, color=color)    
       
    plt.xlabel(x_col)
    plt.ylabel(y_col)
    plt.title(f"{y_col} vs. {x_col}")

    
linear_regression1(data_working, x_col="Union %", y_col="Gini", figsize=(20,10))

# %%
data_working["Gini"].plot.box()

# %%
df1 = data_working[data_working["Region"] != "Latin"]
linear_regression1(df1, x_col="Union %", y_col="Gini", figsize=(20,10), fontsize=18)

# %%
data_working.head()
# Out:
#    Country  Year  Union %   Gini         CPI Group Color
# 0  Hungary  2009     11.9  0.245   95.369304  East     g
# 1  Hungary  2015      9.0  0.291  111.384411  East     g
# 2   Poland  2009     16.3  0.305   97.484226  East     g
# 3   Poland  2010     18.3  0.307  100.000000  East     g
# 4   Poland  2011     17.0  0.304  104.239401  East     g

# %%
data_workin

# %%
mycolormap={'East': 1}

# %%
plt.figure()
data_working.plot.scatter(x="Union %", y="Gini", c="Group", colormap="viridis")
plt.plot(x, regress_values, "r-")

# %%
by_country = data_working.groupby(["Country"])
plt.figure()
by_country.plot.line(x="Year", y="Gini")
by_country.plot.line(x="Year", y="Union %")
# Out:
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# Country
# Australia          AxesSubplot(0.125,0.125;0.775x0.755)
# Austria            AxesSubplot(0.125,0.125;0.775x0.755)
# Belgium            AxesSubplot(0.125,0.125;0.775x0.755)
# Canada             AxesSubplot(0.125,0.125;0.775x0.755)
# Chile              AxesSubplot(0.125,0.125;0.775x0.755)
# Czech Republic     AxesSubplot(0.125,0.125;0.775x0.755)
# Denmark            AxesSubplot(0.125,0.125;0.775x0.755)
# Estonia            AxesSubplot(0.125,0.125;0.775x0.755)
# Finland            AxesSubplot(0.125,0.125;0.775x0.755)
# France             AxesSubplot(0.125,0.125;0.775x0.755)
# Germany            AxesSubplot(0.125,0.125;0.775x0.755)
# Greece             AxesSubplot(0.125,0.125;0.775x0.755)
# Hungary            AxesSubplot(0.125,0.125;0.775x0.755)
# Iceland            AxesSubplot(0.125,0.125;0.775x0.755)
# Ireland            AxesSubplot(0.125,0.125;0.775x0.755)
# Israel             AxesSubplot(0.125,0.125;0.775x0.755)
# Italy              AxesSubplot(0.125,0.125;0.775x0.755)
# Japan              AxesSubplot(0.125,0.125;0.775x0.755)
# Korea              AxesSubplot(0.125,0.125;0.775x0.755)
# Latvia             AxesSubplot(0.125,0.125;0.775x0.755)
# Lithuania          AxesSubplot(0.125,0.125;0.775x0.755)
# Luxembourg         AxesSubplot(0.125,0.125;0.775x0.755)
# Mexico             AxesSubplot(0.125,0.125;0.775x0.755)
# Netherlands        AxesSubplot(0.125,0.125;0.775x0.755)
# New Zealand        AxesSubplot(0.125,0.125;0.775x0.755)
# Norway             AxesSubplot(0.125,0.125;0.775x0.755)
# Poland             AxesSubplot(0.125,0.125;0.775x0.755)
# Portugal           AxesSubplot(0.125,0.125;0.775x0.755)
# Slovak Republic    AxesSubplot(0.125,0.125;0.775x0.755)
# Slovenia           AxesSubplot(0.125,0.125;0.775x0.755)
# Spain              AxesSubplot(0.125,0.125;0.775x0.755)
# Sweden             AxesSubplot(0.125,0.125;0.775x0.755)
# Switzerland        AxesSubplot(0.125,0.125;0.775x0.755)
# Turkey             AxesSubplot(0.125,0.125;0.775x0.755)
# United Kingdom     AxesSubplot(0.125,0.125;0.775x0.755)
# United States      AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
data_working["Union %"].plot.box()

# %%
data_working.groupby(["Year"]).mean()["Union %"].plot.line()

# %%
data_working.groupby(["Year"]).mean()["Gini"].plot.line()

# %%
data_working.groupby(["Year"]).mean()["CPI"].plot.line()

# %%
data_working[["Gini"]].plot.box()

# %%
data_working[["CPI"]].plot.box()

# %%
data_working.plot.scatter(x="Union %", y="CPI")

# %%
data_working[data_working["Year"] == 2018].plot.scatter(x="Gini", y="CPI")

# %%
x = data_working["Gini"]
y = data_working["CPI"]
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(
                                            ,)
regress_values = x * slope + intercept
line_eq = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
plt.figure(figsize=(10,8))
plt.scatter(x, y)
plt.plot(x, regress_values, "r-")
plt.annotate(line_eq, (20,36), fontsize=12, color="darkblue")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-108-4746c8b830fa> in <module>
#       2                                             data_working["Gini"],
#       3                                             data_working["CPI"])
# ----> 4 regress_values = x * slope + intercept
#       5 line_eq = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
#       6 plt.figure(figsize=(10,8))
#
# NameError: name 'x' is not defined

# %% [markdown]
# ### Retirement age population: above 65

# %%
retire = df_09_18[df_09_18["Age group"] == "Retirement age population: above 65"]

gini_retire = retire[retire["MEASURE"] == "GINI"]
gini_retire = gini_retire.drop_duplicates(subset=["Country","Year"])

cpi_retire = retire[retire["MEASURE"] != "GINI"]
cpi_retire = cpi_retire.drop_duplicates(subset=["Country","Year"])

data_retire = pd.merge(gini_retire, cpi_retire, on=["Country", "Year"])\
                        .drop(columns=["MEASURE_x", "Age group_x", "Value_union_y", "MEASURE_y", "Age group_y"])
data_retire = data_retire.rename(columns = {
                                                "Value_union_x": "Union %",
                                                "Value_gini_cpi_x": "Gini",
                                                "Value_gini_cpi_y": "CPI"
                                            })
data_retire.head()
# Out:
#    Country  Year  Union %   Gini         CPI
# 0  Hungary  2009     11.9  0.196   95.369304
# 1  Hungary  2015      9.0  0.233  111.384411
# 2   Poland  2009     16.3  0.262   97.484226
# 3   Poland  2010     18.3  0.261  100.000000
# 4   Poland  2011     17.0  0.255  104.239401

# %% [markdown]
# ### Seperate by gini and cpi to two columns

# %%
gini_df = df_09_18[df_09_18["MEASURE"] == "GINI"]
cpi_df = df_09_18[df_09_18["MEASURE"] != "GINI"]
pd.merge(gini_df, cpi_df, on=["Country", "Year", "Age group"], suffixes=("_gini", "_cpi"))
# Out:
#             Country  Year  Value_union_gini MEASURE_gini  \
# 0           Hungary  2009              11.9         GINI
# 1           Hungary  2009              11.9         GINI
# 2           Hungary  2009              11.9         GINI
# 3           Hungary  2009              11.9         GINI
# 4           Hungary  2009              11.9         GINI
# ...             ...   ...               ...          ...
# 5365  United States  2017              10.3         GINI
# 5366  United States  2017              10.3         GINI
# 5367  United States  2017              10.3         GINI
# 5368  United States  2017              10.3         GINI
# 5369  United States  2017              10.3         GINI
#
#                                 Age group  Value_gini_cpi_gini  \
# 0                        Total population                0.241
# 1                        Total population                0.241
# 2                        Total population                0.241
# 3                        Total population                0.241
# 4                        Total population                0.272
# ...                                   ...                  ...
# 5365                     Total population                0.390
# 5366        Working age population: 18-65                0.383
# 5367        Working age population: 18-65                0.383
# 5368  Retirement age population: above 65                0.411
# 5369  Retirement age population: above 65                0.411
#
#       Value_union_cpi MEASURE_cpi  Value_gini_cpi_cpi
# 0                11.9     CPI2010           95.369304
# 1                11.9     CPI2010           95.369304
# 2                11.9     CPI2015           85.621770
# 3                11.9     CPI2015           85.621770
# 4                11.9     CPI2010           95.369304
# ...               ...         ...                 ...
# 5365             10.3     CPI2015          103.418600
# 5366             10.3     CPI2010          112.411595
# 5367             10.3     CPI2015          103.418600
# 5368             10.3     CPI2010          112.411595
# 5369             10.3     CPI2015          103.418600
#
# [5370 rows x 9 columns]

# %%
gini_df = df[df["MEASURE"] == "GINI"]
gini_df
# Out:
#       Unnamed: 0_union        Country       Source                Series  \
# 0                   55        Hungary  Survey data  Trade union  density
# 1                   55        Hungary  Survey data  Trade union  density
# 4                   55        Hungary  Survey data  Trade union  density
# 5                   55        Hungary  Survey data  Trade union  density
# 8                   55        Hungary  Survey data  Trade union  density
# ...                ...            ...          ...                   ...
# 4007              2424  United States  Survey data  Trade union  density
# 4009              2424  United States  Survey data  Trade union  density
# 4014              2425  United States  Survey data  Trade union  density
# 4016              2425  United States  Survey data  Trade union  density
# 4018              2425  United States  Survey data  Trade union  density
#
#       Year  Unit_union  Value_union  Unnamed: 0_gini_cpi MEASURE  \
# 0     2009  Percentage         11.9                 7947    GINI
# 1     2009  Percentage         11.9                 7959    GINI
# 4     2009  Percentage         11.9                29555    GINI
# 5     2009  Percentage         11.9                29567    GINI
# 8     2009  Percentage         11.9                42679    GINI
# ...    ...         ...          ...                  ...     ...
# 4007  2016  Percentage         10.3                37034    GINI
# 4009  2016  Percentage         10.3                49244    GINI
# 4014  2017  Percentage         10.3                21788    GINI
# 4016  2017  Percentage         10.3                37035    GINI
# 4018  2017  Percentage         10.3                49245    GINI
#
#                                 Age group Unit Code Unit_gini_cpi  \
# 0                        Total population    0_TO_1     0-1 scale
# 1                        Total population    0_TO_1     0-1 scale
# 4           Working age population: 18-65    0_TO_1     0-1 scale
# 5           Working age population: 18-65    0_TO_1     0-1 scale
# 8     Retirement age population: above 65    0_TO_1     0-1 scale
# ...                                   ...       ...           ...
# 4007        Working age population: 18-65    0_TO_1     0-1 scale
# 4009  Retirement age population: above 65    0_TO_1     0-1 scale
# 4014                     Total population    0_TO_1     0-1 scale
# 4016        Working age population: 18-65    0_TO_1     0-1 scale
# 4018  Retirement age population: above 65    0_TO_1     0-1 scale
#
#       Value_gini_cpi
# 0              0.241
# 1              0.272
# 4              0.245
# 5              0.283
# 8              0.196
# ...              ...
# 4007           0.385
# 4009           0.408
# 4014           0.390
# 4016           0.383
# 4018           0.411
#
# [1341 rows x 13 columns]
